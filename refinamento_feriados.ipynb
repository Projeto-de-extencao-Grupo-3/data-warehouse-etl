# %%
import os
import pandas as pd
from glob import glob

# %%
# Juntando os CSVs

df_estadual= pd.read_csv("./trusted/trusted_feriado_estadual.csv")
df_facultativo = pd.read_csv("./trusted/trusted_feriado_facultativo.csv")
df_nacional = pd.read_csv("./trusted/trusted_feriado_nacional.csv")
df_municipal = pd.read_csv("./trusted/trusted_feriado_municipal.csv")

df_final = pd.concat([df_estadual, df_facultativo, df_nacional, df_municipal], ignore_index=True)

df_final.to_csv("./trusted/trusted_feriados.csv", index=False)

# %%
# Adicionando coluna mês a partir da coluna data

df_final["MES"] = pd.to_datetime(df_final["DATA"], errors="coerce").dt.month

df_final.to_csv("./refined/refined_feriados_mes.csv", index=False)
# Out:
# /tmp/ipykernel_272177/2398078987.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df_final["MES"] = pd.to_datetime(df_final["DATA"], errors="coerce").dt.month

# %%
# Pegando os dados de feriados apenas do estado de São Paulo

df_final = df_final[df_final["ESTADO"] == "SP"]

df_final.to_csv("./refined/refined_feriados_sp.csv", index=False)
